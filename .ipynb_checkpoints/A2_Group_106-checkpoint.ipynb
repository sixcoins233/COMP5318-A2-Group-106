# %%
import time
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import top_k_accuracy_score

import tensorflow_model_optimization as tfmot

import keras_tuner as kt

gpus = tf.config.list_physical_devices('GPU')
print("GPU Available: ", gpus)
# Out:
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Ultility

# %%
def visualize_emnist_samples(data, labels):
    # get all the unique labels and number of it
    unique_labels = np.unique(labels)
    num_labels = len(unique_labels)
    
    # create a dict to store all the index for each unique label
    label_to_index = {}
    for label in unique_labels:
        label_to_index[label] = np.where(labels == label)[0][0]
        
    # calculate the suit size of diagram
    n_cols = math.ceil(math.sqrt(num_labels))
    n_rows = math.ceil(num_labels / n_cols)

    # graph style setting
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 15))
    fig.suptitle("EMNIST Samples (First image for each label)", fontsize=16)
    
    for i, label in enumerate(unique_labels):
        row = i // n_cols
        col = i % n_cols
        
        # get the first image for each label
        img = data[label_to_index[label]]

        # get current axes for eliminate the rest empty diagram
        if n_rows > 1:
            ax = axes[row, col]
        else:
            ax = axes[col]
        
        # plt
        axes[row, col].imshow(img, cmap='gray')
        axes[row, col].axis('off')
        axes[row, col].set_title(f"Label: {label}")

    # remove rest empty diagram
    for i in range(num_labels, n_rows * n_cols):
        row = i // n_cols
        col = i % n_cols
        if n_rows > 1:
            fig.delaxes(axes[row, col])
        else:
            fig.delaxes(axes[col])
    
    plt.tight_layout()
    plt.show()

# %%
def visualize_predictions(model, x, y, num_images=25):
    predictions = model.predict(x[:num_images])
    fig, axes = plt.subplots(5, 5, figsize=(15, 15))
    for i, ax in enumerate(axes.flat):
        ax.imshow(x[i].reshape(32,32), cmap='gray')
        true_label = y[i]
        pred_label = np.argmax(predictions[i])
        ax.set_title(f"True: {true_label}, Pred: {pred_label}")
        ax.axis('off')
    plt.tight_layout()
    plt.show()

# %%
# Ultility function 1: Training Time Monitoring using tensorflow
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
# Ultility function 2: Measure reasoning time
def measure_reasoning_time(model, X):
    start = time.time()
    model.predict(X)
    end = time.time()
    return end - start

# %%
# Ultility function 3: Measure the computational complexity of the model (FLOPs)
from tensorflow.python.framework import convert_to_constants
def get_flops(model):
    # Define the input shape for the model
    input_shape = (1,) + model.input_shape[1:]
    
    # Create a concrete function from the model
    inputs = tf.TensorSpec(shape=input_shape, dtype=tf.float32)
    concrete_function = tf.function(model).get_concrete_function(inputs)
    
    # Convert variables to constants
    frozen_func = convert_to_constants.convert_variables_to_constants_v2(concrete_function)
    graph_def = frozen_func.graph.as_graph_def()
    
    # Import the graph definition
    with tf.Graph().as_default() as graph:
        tf.compat.v1.import_graph_def(graph_def, name='')
        run_meta = tf.compat.v1.RunMetadata()
        opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()
        
        # Run the profiler to calculate FLOPs
        flops = tf.compat.v1.profiler.profile(graph=graph, run_meta=run_meta, cmd='scope', options=opts)
        
    # Return the total FLOPs
    return flops.total_float_ops if flops is not None else 0

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
# Load the EMNIST data
train_dict = pd.read_pickle('emnist_train.pkl')
test_dict = pd.read_pickle('emnist_test.pkl')

# %%
# Convert the data to np arrays
train_images = np.array(train_dict['data'])
train_labels = np.array(train_dict['labels'])
test_images = np.array(test_dict['data'])
test_labels = np.array(test_dict['labels'])

# %%
# Add a channel dimension
train_images = train_images[..., np.newaxis]
test_images = test_images[..., np.newaxis]

# %%
# Resize the images to 32x32
train_images = np.array(tf.image.resize(train_images, [32, 32]))
test_images = np.array(tf.image.resize(test_images, [32, 32]))

# %%
# Normalize the images
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Create TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
print("Train Dataset:", train_dataset)
print("Test Dataset:", test_dataset)
# Out:
# Train Dataset: <TensorSliceDataset element_spec=(TensorSpec(shape=(32, 32, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>
# Test Dataset: <TensorSliceDataset element_spec=(TensorSpec(shape=(32, 32, 1), dtype=tf.float32, name=None), TensorSpec(shape=(), dtype=tf.int64, name=None))>

# %%
visualize_emnist_samples(train_images, train_labels)

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %% [markdown]
# ## Model: Standard CNN

# %% [markdown]
# ### 1. Implement CNN Network Structure

# %%
# Define the model
def cnn_model(input_shape, num_classes):
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))

    # Conv layer 1
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))

    # Conv layer 2
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0))

    # Conv layer 3
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Flatten())
    model.add(layers.Dropout(0))

    # Dense layer
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.2))

    model.add(layers.Dense(num_classes, activation='softmax'))
    return model

# %%
std_model = cnn_model((32, 32, 1), 62)

optimizer = keras.optimizers.Adam(learning_rate=1e-4)
std_model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

std_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        640
#
#  batch_normalization (BatchN  (None, 30, 30, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 64)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_1 (Batc  (None, 13, 13, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         147584
#
#  batch_normalization_2 (Batc  (None, 4, 4, 128)        512
#  hNormalization)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_3 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 62)                15934
#
# =================================================================
# Total params: 764,862
# Trainable params: 763,710
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
# Train the baseline model
std_time_callback = TimeHistory()
std_model.fit(datagen.flow(train_images, train_labels, batch_size=32), epochs=10, callbacks=[std_time_callback])

total_training_time = sum(std_time_callback.times)
print(f"Total training time: {total_training_time} seconds")

# Evaluate the model
std_loss, std_accuracy = std_model.evaluate(test_dataset.batch(64))
print(f"Test accuracy: {std_accuracy}")
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 42s 11ms/step - loss: 1.3419 - accuracy: 0.6375
# Epoch 2/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.7319 - accuracy: 0.7685
# Epoch 3/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.6163 - accuracy: 0.7958
# Epoch 4/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.5568 - accuracy: 0.8100
# Epoch 5/10
# 3125/3125 [==============================] - 32s 10ms/step - loss: 0.5249 - accuracy: 0.8182
# Epoch 6/10
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.4987 - accuracy: 0.8259
# Epoch 7/10
# 3125/3125 [==============================] - 32s 10ms/step - loss: 0.4804 - accuracy: 0.8306
# Epoch 8/10
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.4638 - accuracy: 0.8356
# Epoch 9/10
# 3125/3125 [==============================] - 32s 10ms/step - loss: 0.4532 - accuracy: 0.8374
# Epoch 10/10
# 3125/3125 [==============================] - 32s 10ms/step - loss: 0.4454 - accuracy: 0.8402
# Total training time: 334.74856209754944 seconds
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4014 - accuracy: 0.8563
# Test accuracy: 0.8562999963760376

# %%
visualize_predictions(std_model, test_images, test_labels)
# Out:
# 1/1 [==============================] - 0s 199ms/step

# %%
# Visualize hidden layers output
layer_outputs = [layer.output for layer in std_model.layers if 'max_pooling2d' in layer.name]
activation_model = models.Model(inputs=std_model.input, outputs=layer_outputs)
activations = activation_model.predict(test_images[0][np.newaxis, ...])
layer_names = [layer.name for layer in std_model.layers if 'max_pooling2d' in layer.name]
for layer_name, layer_activation in zip(layer_names, activations):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]      
    plt.figure(figsize=(12,12))
    for i in range(n_features):
        # Display only the first 64 features
        if i >= 64:
            break
        plt.subplot(8, 8, i + 1)
        plt.imshow(layer_activation[0, :, :, i], cmap='viridis')
        plt.axis('off')
    plt.suptitle(f"Layer: {layer_name}")
    plt.show()
# Out:
# 1/1 [==============================] - 0s 99ms/step

# %% [markdown]
# ### 2. Hyperparameter tuning

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
lr_reducer = ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-6)

# %%
# train with best model
best_std_model = cnn_model((32, 32, 1), 62)
optimizer = keras.optimizers.Adam(learning_rate=1e-4)
loss = keras.losses.SparseCategoricalCrossentropy()
best_std_model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
history = best_std_model.fit(
    datagen.flow(train_images, train_labels, batch_size=32),
    epochs=50,
    validation_data=(test_images, test_labels),
    callbacks=[early_stopping, lr_reducer]
)
# Out:
# Epoch 1/50
# 3125/3125 [==============================] - 33s 10ms/step - loss: 1.3650 - accuracy: 0.6331 - val_loss: 0.5875 - val_accuracy: 0.8015 - lr: 1.0000e-04
# Epoch 2/50
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.7426 - accuracy: 0.7645 - val_loss: 0.4995 - val_accuracy: 0.8307 - lr: 1.0000e-04
# Epoch 3/50
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.6220 - accuracy: 0.7938 - val_loss: 0.4566 - val_accuracy: 0.8405 - lr: 1.0000e-04
# Epoch 4/50
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.5630 - accuracy: 0.8075 - val_loss: 0.4306 - val_accuracy: 0.8503 - lr: 1.0000e-04
# Epoch 5/50
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.5268 - accuracy: 0.8186 - val_loss: 0.4291 - val_accuracy: 0.8515 - lr: 1.0000e-04
# Epoch 6/50
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.5008 - accuracy: 0.8262 - val_loss: 0.4256 - val_accuracy: 0.8499 - lr: 1.0000e-04
# Epoch 7/50
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.4827 - accuracy: 0.8291 - val_loss: 0.4045 - val_accuracy: 0.8551 - lr: 1.0000e-04
# Epoch 8/50
# 3125/3125 [==============================] - 32s 10ms/step - loss: 0.4655 - accuracy: 0.8343 - val_loss: 0.4062 - val_accuracy: 0.8494 - lr: 1.0000e-04
# Epoch 9/50
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.4544 - accuracy: 0.8375 - val_loss: 0.4018 - val_accuracy: 0.8554 - lr: 1.0000e-04
# Epoch 10/50
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.4442 - accuracy: 0.8412 - val_loss: 0.3968 - val_accuracy: 0.8552 - lr: 1.0000e-04
# Epoch 11/50
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.4383 - accuracy: 0.8422 - val_loss: 0.3938 - val_accuracy: 0.8557 - lr: 1.0000e-04
# Epoch 12/50
# 3125/3125 [==============================] - 32s 10ms/step - loss: 0
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.3507 - accuracy: 0.8670 - val_loss: 0.3816 - val_accuracy: 0.8597 - lr: 5.0000e-05
# Epoch 34/50
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.3502 - accuracy: 0.8676 - val_loss: 0.3743 - val_accuracy: 0.8637 - lr: 5.0000e-05
# Epoch 35/50
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.3453 - accuracy: 0.8683 - val_loss: 0.3768 - val_accuracy: 0.8638 - lr: 5.0000e-05

# %%
# evaluate
test_loss, test_acc = best_std_model.evaluate(test_images, test_labels, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 625/625 - 1s - loss: 0.3725 - accuracy: 0.8641 - 1s/epoch - 2ms/step
#
# Test accuracy: 0.8640999794006348

# %%
# saving model
best_std_model.save('emnist_model_optimized')
print("Optimized model saved")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: emnist_model_optimized\assets
# INFO:tensorflow:Assets written to: emnist_model_optimized\assets
# Optimized model saved

# %%
# result diagram
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Evaluate the model
y_pred = best_std_model.predict(test_dataset.batch(64))
y_pred = np.argmax(y_pred, axis=1)
y_true = test_labels

std_accuracy = accuracy_score(y_true, y_pred)
std_precision = precision_score(y_true, y_pred, average='weighted')
std_recall = recall_score(y_true, y_pred, average='weighted')
std_f1 = f1_score(y_true, y_pred, average='weighted')
std_top5_accuracy = top_k_accuracy_score(y_true, best_std_model.predict(test_dataset.batch(64)), k=5)

print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 1s 3ms/step
#  58/313 [====>.........................] - ETA: 0s
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 313/313 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.64      0.87      0.74       976
#            1       0.65      0.91      0.76      1023
#            2       0.95      0.98      0.96      1003
#            3       1.00      0.99      1.00      1035
#            4       0.98      0.97      0.97       903
#            5       0.93      0.97      0.95       928
#            6       0.97      0.98      0.98       959
#            7       0.99      1.00      0.99      1098
#            8       0.98      0.98      0.98       941
#            9       0.93      0.98      0.95       929
#           10       0.94      0.99      0.97       170
#           11       0.93      0.97      0.95       118
#           12       0.76      0.97      0.85       316
#           13       0.88      0.95      0.91       128
#           14       0.93      0.98      0.95       162
#           15       0.82      0.97      0.89       261
#           16       0.83      0.92      0.87        60
#           17       0.89      0.99      0.94        74
#           18       0.67      0.43      0.53       350
#           19       0.80      0.92      0.85        95
#           20       0.55      0.89      0.68        71
#           21       0.88      0.97      0.93       141
#           22       0.77      0.98      0.86       273
#           23       0.96      0.99      0.97       249
#           24       0.70      0.43      0.53       741
#           25       0.82      0.94      0.88       277
#           26       0.86      0.94      0.90        67
#           27       0.94      0.97      0.96       160
#           28       0.84      0.90      0.87       624
#           29       0.94      0.90      0.92       249
#           30       0.78      0.97      0.87       342
#           31       0.66      0.78      0.71       126
#           32       0.72      0.93      0.81       125
#           33       0.56      0.93      0.70        85
#           34       0.69      0.89      0.77       141
#           35       0.56      0.71      0.62        62
#           36       0.94      0.90      0.92       278
#           37       0.94      0.85      0.89       170
#           38       0.29      0.02      0.04        90
#           39       0.97      0.97      0.97       297
#           40       0.99      0.98      0.99       709
#           41       0.33      0.02      0.03        57
#           42       0.76      0.43      0.55        97
#           43       0.95      0.94      0.95       269
#           44       0.86      0.41      0.55        76
#           45       0.87      0.57      0.69        60
#           46       0.81      0.36      0.50        83
#           47       0.52      0.21      0.30       421
#           48       0.29      0.03      0.05        75
#           49       0.96      0.93      0.95       332
#           50       0.00      0.00      0.00        79
#           51       0.50      0.22      0.30        65
#           52       0.68      0.38      0.49        68
#           53       0.97      0.95      0.96       411
#           54       0.50      0.03      0.05        79
#           55       0.93      0.96      0.95       502
#           56       0.61      0.16      0.25        89
#           57       0.67      0.32      0.43        88
#           58       0.85      0.55      0.67        93
#           59       0.90      0.40      0.55       107
#           60       0.48      0.23      0.31        60
#           61       0.78      0.39      0.52        83
#
#     accuracy                           0.86     20000
#    macro avg       0.78      0.73      0.72     20000
# weighted avg       0.85      0.86      0.85     20000
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Model: VGG11

# %% [markdown]
# ### 1. Implement VGG11 Network Structure

# %%
def VGG11(input_shape, num_classes=62):
    model = models.Sequential()
    model.add(layers.Input(shape=input_shape))
    
    # Conv Layer Block 1
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    # Conv Layer Block 2
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    # Conv Layer Block 3
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    # Conv Layer Block 4
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    
    # Classifier
    model.add(layers.Flatten())
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))
    
    return model

# %%
# Create VGG11 baseline model
vgg11_model = VGG11(input_shape=(32, 32, 1), num_classes=62)

optimizer = keras.optimizers.Adam(learning_rate=1e-4)
loss = keras.losses.SparseCategoricalCrossentropy()
vgg11_model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

vgg11_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)        640
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 256)         295168
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 256)         590080
#
#  max_pooling2d_6 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  max_pooling2d_7 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 512)               1049088
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 512)               262656
#
#  dropout_9 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 62)                31806
#
# =================================================================
# Total params: 5,843,262
# Trainable params: 5,843,262
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train VGG11 baseline model and measure the training time
vgg11_time_callback = TimeHistory()

history = vgg11_model.fit(datagen.flow(train_images, train_labels, batch_size=32), validation_data=test_dataset.batch(64), epochs=10, callbacks=[vgg11_time_callback])

total_training_time = sum(vgg11_time_callback.times)
print(f"Total training time: {total_training_time:.2f} seconds")

# Evaluate the VGG11 model
loss, acc = vgg11_model.evaluate(test_dataset.batch(64))
print(f"Test Accuracy: {acc}")
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.3757 - accuracy: 0.8597 - val_loss: 0.3850 - val_accuracy: 0.8582
# Epoch 2/10
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.3697 - accuracy: 0.8626 - val_loss: 0.3826 - val_accuracy: 0.8593
# Epoch 3/10
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.3636 - accuracy: 0.8638 - val_loss: 0.3872 - val_accuracy: 0.8597
# Epoch 4/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.3595 - accuracy: 0.8647 - val_loss: 0.3728 - val_accuracy: 0.8624
# Epoch 5/10
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.3533 - accuracy: 0.8672 - val_loss: 0.3749 - val_accuracy: 0.8644
# Epoch 6/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.3500 - accuracy: 0.8668 - val_loss: 0.3860 - val_accuracy: 0.8578
# Epoch 7/10
# 3125/3125 [==============================] - 34s 11ms/step - loss: 0.3446 - accuracy: 0.8681 - val_loss: 0.3678 - val_accuracy: 0.8627
# Epoch 8/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.3420 - accuracy: 0.8694 - val_loss: 0.3774 - val_accuracy: 0.8597
# Epoch 9/10
# 3125/3125 [==============================] - 33s 10ms/step - loss: 0.3348 - accuracy: 0.8709 - val_loss: 0.3796 - val_accuracy: 0.8632
# Epoch 10/10
# 3125/3125 [==============================] - 33s 11ms/step - loss: 0.3310 - accuracy: 0.8727 - val_loss: 0.3717 - val_accuracy: 0.8630
# Total training time: 332.03 seconds
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3717 - accuracy: 0.8630
# Test Accuracy: 0.8629500269889832

# %%
# Plot the loss vs epoch graph
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Visualize hidden layers output
layer_outputs = [layer.output for layer in vgg11_model.layers if 'max_pooling2d' in layer.name]
activation_model = models.Model(inputs=vgg11_model.input, outputs=layer_outputs)
activations = activation_model.predict(test_images[0][np.newaxis, ...])
layer_names = [layer.name for layer in vgg11_model.layers if 'max_pooling2d' in layer.name]
for layer_name, layer_activation in zip(layer_names, activations):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]      
    plt.figure(figsize=(12,12))
    for i in range(n_features):
        # Display only the first 64 features
        if i >= 64:
            break
        plt.subplot(8, 8, i + 1)
        plt.imshow(layer_activation[0, :, :, i], cmap='viridis')
        plt.axis('off')
    plt.suptitle(f"Layer: {layer_name}")
    plt.show()
# Out:
# 1/1 [==============================] - 0s 142ms/step

# %% [markdown]
# ### 2. Hyperparameter tuning

# %%
# Define a function to create the model
def create_model_vgg11(learning_rate, optimizer_name):
    optimizer_dict = {
    'adam': keras.optimizers.Adam,
    'adagrad': keras.optimizers.Adagrad,
    'rmsprop': keras.optimizers.RMSprop
    }
    if optimizer_name in optimizer_dict:
        optimizer = optimizer_dict[optimizer_name](learning_rate=learning_rate)
    else:
        raise ValueError(f"Unknown optimizer: {optimizer_name}")
    model = VGG11(input_shape=(32, 32, 1), num_classes=62)
    loss = keras.losses.SparseCategoricalCrossentropy()
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %%
# Define the hyperparameters
param_grid = {
    'model__learning_rate': [1e-5, 5e-5, 1e-4],
    'model__optimizer_name': ['adam', 'adagrad','rmsprop']
    
    # Debug parameters
    # 'model__learning_rate': [1e-4],
    # 'model__optimizer_name': ['adam']
}

# %%
# Wrap the model using KerasClassifier
# Use scikeras.wrappers.KerasClassifier to wrap the model.
keras_model = KerasClassifier(model=create_model_vgg11, epochs=10)

# Perform the grid search
skf = StratifiedKFold(n_splits=3, shuffle=True)
grid = GridSearchCV(estimator=keras_model, param_grid=param_grid, cv=skf)
grid_result = grid.fit(train_images, train_labels)
# Out:
# Epoch 1/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 2.9689 - accuracy: 0.2854
# Epoch 2/10
# 2084/2084 [==============================] - 12s 6ms/step - loss: 1.8785 - accuracy: 0.5361
# Epoch 3/10
# 2084/2084 [==============================] - 12s 6ms/step - loss: 1.5103 - accuracy: 0.6090
# Epoch 4/10
# 2084/2084 [==============================] - 12s 6ms/step - loss: 1.2908 - accuracy: 0.6519
# Epoch 5/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 1.1423 - accuracy: 0.6795
# Epoch 6/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 1.0354 - accuracy: 0.7047
# Epoch 7/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 0.9554 - accuracy: 0.7191
# Epoch 8/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 0.8865 - accuracy: 0.7356
# Epoch 9/10
# 2084/2084 [==============================] - 12s 6ms/step - loss: 0.8366 - accuracy: 0.7474
# Epoch 10/10
# 2084/2084 [==============================] - 12s 6ms/step - loss: 0.7925 - accuracy: 0.7557
# 1042/1042 [==============================] - 2s 2ms/step
# Epoch 1/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 2.9293 - accuracy: 0.2970
# Epoch 2/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 1.8131 - accuracy: 0.5463
# Epoch 3/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 1
10
# 2084/2084 [==============================] - 17s 8ms/step - loss: 0.4469 - accuracy: 0.8510
# Epoch 10/10
# 2084/2084 [==============================] - 17s 8ms/step - loss: 0.4480 - accuracy: 0.8494
# 1042/1042 [==============================] - 2s 2ms/step
# Epoch 1/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 1.3013 - accuracy: 0.6438
# Epoch 2/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.5988 - accuracy: 0.8028
# Epoch 3/10
# 3125/3125 [==============================] - 21s 7ms/step - loss: 0.4940 - accuracy: 0.8298
# Epoch 4/10
# 3125/3125 [==============================] - 19s 6ms/step - loss: 0.4441 - accuracy: 0.8433
# Epoch 5/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.4088 - accuracy: 0.8525
# Epoch 6/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.3812 - accuracy: 0.8616
# Epoch 7/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.3600 - accuracy: 0.8655
# Epoch 8/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.3400 - accuracy: 0.8706
# Epoch 9/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.3236 - accuracy: 0.8756
# Epoch 10/10
# 3125/3125 [==============================] - 18s 6ms/step - loss: 0.3077 - accuracy: 0.8803

# %%
# Print the results
# Mean measures the best-performing hyperparameter combination.
# Standard deviation measures the stability of the model's performance.
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, std, param))
# Out:
# Best: 0.857410 using {'model__learning_rate': 0.0001, 'model__optimizer_name': 'adam'}
# 0.814480 (0.001164) with: {'model__learning_rate': 1e-05, 'model__optimizer_name': 'adam'}
# 0.073990 (0.014929) with: {'model__learning_rate': 1e-05, 'model__optimizer_name': 'adagrad'}
# 0.806900 (0.006105) with: {'model__learning_rate': 1e-05, 'model__optimizer_name': 'rmsprop'}
# 0.853100 (0.001031) with: {'model__learning_rate': 5e-05, 'model__optimizer_name': 'adam'}
# 0.057860 (0.008415) with: {'model__learning_rate': 5e-05, 'model__optimizer_name': 'adagrad'}
# 0.851370 (0.003331) with: {'model__learning_rate': 5e-05, 'model__optimizer_name': 'rmsprop'}
# 0.857410 (0.001273) with: {'model__learning_rate': 0.0001, 'model__optimizer_name': 'adam'}
# 0.301830 (0.005071) with: {'model__learning_rate': 0.0001, 'model__optimizer_name': 'adagrad'}
# 0.842130 (0.016448) with: {'model__learning_rate': 0.0001, 'model__optimizer_name': 'rmsprop'}

# %%
# Train the model with the best hyperparameters
best_lr_vgg11 = grid_result.best_params_['model__learning_rate']
best_opt_vgg11 = grid_result.best_params_['model__optimizer_name']
best_model_vgg11 = create_model_vgg11(best_lr_vgg11, best_opt_vgg11)
history = best_model_vgg11.fit(train_dataset.batch(64), validation_data=test_dataset.batch(64), epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.4838 - accuracy: 0.6029 - val_loss: 0.5966 - val_accuracy: 0.8009
# Epoch 2/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6736 - accuracy: 0.7839 - val_loss: 0.4765 - val_accuracy: 0.8360
# Epoch 3/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5497 - accuracy: 0.8154 - val_loss: 0.4384 - val_accuracy: 0.8464
# Epoch 4/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4876 - accuracy: 0.8314 - val_loss: 0.4254 - val_accuracy: 0.8504
# Epoch 5/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4467 - accuracy: 0.8419 - val_loss: 0.4083 - val_accuracy: 0.8536
# Epoch 6/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4158 - accuracy: 0.8506 - val_loss: 0.4023 - val_accuracy: 0.8572
# Epoch 7/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3902 - accuracy: 0.8577 - val_loss: 0.4042 - val_accuracy: 0.8593
# Epoch 8/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3657 - accuracy: 0.8638 - val_loss: 0.4014 - val_accuracy: 0.8602
# Epoch 9/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3486 - accuracy: 0.8680 - val_loss: 0.4127 - val_accuracy: 0.8610
# Epoch 10/10
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3302 - accuracy: 0.8744 - val_loss: 0.4158 - val_accuracy: 0.8587

# %%
y_pred = best_model_vgg11.predict(test_dataset.batch(64))
y_pred = np.argmax(y_pred, axis=1)
y_true = test_labels

vgg11_accuracy = accuracy_score(y_true, y_pred)
vgg11_precision = precision_score(y_true, y_pred, average='weighted')
vgg11_recall = recall_score(y_true, y_pred, average='weighted')
vgg11_f1 = f1_score(y_true, y_pred, average='weighted')
vgg11_top5_accuracy = top_k_accuracy_score(y_true, best_model_vgg11.predict(test_dataset.batch(64)), k=5)

print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 1s 2ms/step
#  48/313 [===>..........................] - ETA: 0s
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 313/313 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.67      0.79      0.73       976
#            1       0.68      0.92      0.78      1023
#            2       0.94      0.98      0.96      1003
#            3       0.98      0.99      0.99      1035
#            4       0.95      0.98      0.97       903
#            5       0.96      0.91      0.94       928
#            6       0.96      0.98      0.97       959
#            7       0.98      0.99      0.99      1098
#            8       0.97      0.97      0.97       941
#            9       0.93      0.97      0.95       929
#           10       0.95      0.95      0.95       170
#           11       0.93      0.82      0.87       118
#           12       0.76      0.90      0.82       316
#           13       0.93      0.84      0.89       128
#           14       0.90      1.00      0.94       162
#           15       0.84      0.91      0.87       261
#           16       0.87      0.88      0.88        60
#           17       0.89      0.96      0.92        74
#           18       0.59      0.49      0.53       350
#           19       0.85      0.83      0.84        95
#           20       0.67      0.72      0.69        71
#           21       0.87      0.96      0.91       141
#           22       0.78      0.97      0.86       273
#           23       0.93      0.98      0.95       249
#           24       0.63      0.57      0.60       741
#           25       0.86      0.84      0.85       277
#           26       0.97      0.87      0.91        67
#           27       0.96      0.93      0.94       160
#           28       0.79      0.96      0.86       624
#           29       0.89      0.92      0.91       249
#           30       0.75      0.97      0.84       342
#           31       0.72      0.58      0.64       126
#           32       0.84      0.74      0.79       125
#           33       0.65      0.81      0.72        85
#           34       0.77      0.69      0.73       141
#           35       0.59      0.77      0.67        62
#           36       0.91      0.89      0.90       278
#           37       0.92      0.82      0.87       170
#           38       0.42      0.17      0.24        90
#           39       0.97      0.96      0.96       297
#           40       0.97      0.98      0.98       709
#           41       0.40      0.21      0.28        57
#           42       0.57      0.44      0.50        97
#           43       0.97      0.91      0.94       269
#           44       0.84      0.41      0.55        76
#           45       0.74      0.65      0.69        60
#           46       0.74      0.69      0.71        83
#           47       0.55      0.19      0.28       421
#           48       0.00      0.00      0.00        75
#           49       0.95      0.92      0.94       332
#           50       0.00      0.00      0.00        79
#           51       0.51      0.46      0.48        65
#           52       0.68      0.34      0.45        68
#           53       0.96      0.93      0.95       411
#           54       0.00      0.00      0.00        79
#           55       0.94      0.94      0.94       502
#           56       0.67      0.02      0.04        89
#           57       0.59      0.55      0.56        88
#           58       0.74      0.83      0.78        93
#           59       0.79      0.60      0.68       107
#           60       0.43      0.37      0.40        60
#           61       0.72      0.41      0.52        83
#
#     accuracy                           0.86     20000
#    macro avg       0.76      0.73      0.73     20000
# weighted avg       0.85      0.86      0.85     20000
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Model: ResNet18

# %% [markdown]
# ### 1. Implement ResNet18 Network Structure
# K. He, X. Zhang, S. Ren and J. Sun, "Deep Residual Learning for Image Recognition," 2016 IEEE Conference on Computer Vision and Pattern Recognition (CVPR), Las Vegas, NV, USA, 2016, pp. 770-778, doi: 10.1109/CVPR.2016.90.

# %%
def residual_block(x, filters, kernel_size=3, downsample=False):
    shortcut = x

    x = layers.Conv2D(filters, kernel_size=kernel_size, strides=(2 if downsample else 1), padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same', activation='relu')(x)
    x = layers.BatchNormalization()(x)

    # Add downsample layer
    if downsample:
        shortcut = layers.Conv2D(filters, kernel_size=1, strides=2, padding='same')(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    # Add shortcut connection
    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    
    return x

def ResNet18(input_shape, num_classes=62):
    inputs = layers.Input(shape=input_shape)

    # Conv Layer Block 1
    x = layers.Conv2D(64, (7, 7), strides=2, padding='same', activation='relu')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((3, 3), strides=2, padding='same')(x)

    # Residual Block 1
    x = residual_block(x, filters=64)
    x = residual_block(x, filters=64)

    # Residual Block 2
    x = residual_block(x, filters=128, downsample=True)
    x = residual_block(x, filters=128)

    # Residual Block 3
    x = residual_block(x, filters=256, downsample=True)
    x = residual_block(x, filters=256)

    # Residual Block 4
    # x = residual_block(x, filters=512, downsample=True)
    # x = residual_block(x, filters=512)

    # Classifier
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    
    return model

# %%
# Create ResNet18 baseline model
resnet18_model = ResNet18(input_shape=(32, 32, 1), num_classes=62)

optimizer = keras.optimizers.Adam(learning_rate=1e-5)
loss = keras.losses.SparseCategoricalCrossentropy()
resnet18_model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

resnet18_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_33 (InputLayer)          [(None, 32, 32, 1)]  0           []
#
#  conv2d_186 (Conv2D)            (None, 16, 16, 64)   3200        ['input_33[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 64)  256         ['conv2d_186[0][0]']
#  rmalization)
#
#  max_pooling2d_124 (MaxPooling2  (None, 8, 8, 64)    0           ['batch_normalization_8[0][0]']
#  D)
#
#  conv2d_187 (Conv2D)            (None, 8, 8, 64)     36928       ['max_pooling2d_124[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_187[0][0]']
#  rmalization)
#
#  conv2d_188 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 64)    256         ['conv2d_188[0][0]']
#  ormalization)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['batch_normalization_10[0][0]',
#                                                                   'max_pooling2d_124[0][0]']
#
#  activation (Activation)        (None, 8, 8, 64)     0           ['add[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 8, 8, 64)     36928       ['activation[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 8, 8, 64)    256         ['conv2d_189[0][0]']
#  ormalization)
#
#  conv2d_190 (Conv2D)            (None, 8, 8, 64)     36928       ['batch_normalization_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 8, 64)    256         ['conv2d_190[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_12[0][0]',
#                                                                   'activation[0][0]']
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 4, 4, 128)    73856       ['activation_1[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 4, 4, 128)   512         ['conv2d_191[0][0]']
#  ormalization)
#
#  conv2d_192 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_13[0][0]']
#
#  conv2d_193 (Conv2D)            (None, 4, 4, 128)    8320        ['activation_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 128)   512         ['conv2d_192[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 128)   512         ['conv2d_193[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_14[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  activation_2 (Activation)      (None, 4, 4, 128)    0           ['add_2[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_2[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 4, 4, 128)   512         ['conv2d_194[0][0]']
#  ormalization)
#
#  conv2d_195 (Conv2D)            (None, 4, 4, 128)    147584      ['batch_normalization_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 4, 4, 128)   512         ['conv2d_195[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_17[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  conv2d_196 (Conv2D)            (None, 2, 2, 256)    295168      ['activation_3[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_196[0][0]']
#  ormalization)
#
#  conv2d_197 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_18[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 2, 2, 256)    33024       ['activation_3[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_197[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_198[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  activation_4 (Activation)      (None, 2, 2, 256)    0           ['add_4[0][0]']
#
#  conv2d_199 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_4[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_199[0][0]']
#  ormalization)
#
#  conv2d_200 (Conv2D)            (None, 2, 2, 256)    590080      ['batch_normalization_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_200[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_22[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 2, 2, 256)    0           ['add_5[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['activation_5[0][0]']
#  alAveragePooling2D)
#
#  dropout_68 (Dropout)           (None, 256)          0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_94 (Dense)               (None, 62)           15934       ['dropout_68[0][0]']
#
# ==================================================================================================
# Total params: 2,799,166
# Trainable params: 2,794,686
# Non-trainable params: 4,480
# __________________________________________________________________________________________________

# %%
# Train the baseline model
resnet18_time_callback = TimeHistory()

history = resnet18_model.fit(datagen.flow(train_images, train_labels, batch_size=32),validation_data=test_dataset.batch(64),epochs=10,callbacks=[resnet18_time_callback])

total_training_time = sum(resnet18_time_callback.times)
print(f"Total training time: {total_training_time:.2f} seconds")
# Out:
# Epoch 1/10
# 3125/3125 [==============================] - 46s 14ms/step - loss: 3.3235 - accuracy: 0.2726 - val_loss: 1.5696 - val_accuracy: 0.6089
# Epoch 2/10
# 3125/3125 [==============================] - 43s 14ms/step - loss: 1.8194 - accuracy: 0.5423 - val_loss: 0.9603 - val_accuracy: 0.7269
# Epoch 3/10
# 3125/3125 [==============================] - 44s 14ms/step - loss: 1.3029 - accuracy: 0.6462 - val_loss: 0.7048 - val_accuracy: 0.7872
# Epoch 4/10
# 3125/3125 [==============================] - 44s 14ms/step - loss: 1.0205 - accuracy: 0.7065 - val_loss: 0.6052 - val_accuracy: 0.8080
# Epoch 5/10
# 3125/3125 [==============================] - 43s 14ms/step - loss: 0.8727 - accuracy: 0.7392 - val_loss: 0.5315 - val_accuracy: 0.8241
# Epoch 6/10
# 3125/3125 [==============================] - 44s 14ms/step - loss: 0.7785 - accuracy: 0.7599 - val_loss: 0.5073 - val_accuracy: 0.8291
# Epoch 7/10
# 3125/3125 [==============================] - 44s 14ms/step - loss: 0.7106 - accuracy: 0.7764 - val_loss: 0.4810 - val_accuracy: 0.8353
# Epoch 8/10
# 3125/3125 [==============================] - 44s 14ms/step - loss: 0.6668 - accuracy: 0.7868 - val_loss: 0.4619 - val_accuracy: 0.8410
# Epoch 9/10
# 3125/3125 [==============================] - 44s 14ms/step - loss: 0.6302 - accuracy: 0.7968 - val_loss: 0.4610 - val_accuracy: 0.8413
# Epoch 10/10
# 3125/3125 [==============================] - 45s 14ms/step - loss: 0.6018 - accuracy: 0.8033 - val_loss: 0.4490 - val_accuracy: 0.8439
# Total training time: 442.27 seconds

# %%
# Plot the loss vs epoch graph
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Visualize hidden layers output
layer_outputs = [layer.output for layer in resnet18_model.layers if 'conv2d' in layer.name]
activation_model = models.Model(inputs=resnet18_model.input, outputs=layer_outputs)
activations = activation_model.predict(test_images[0][np.newaxis, ...])
layer_names = [layer.name for layer in resnet18_model.layers if 'conv2d' in layer.name]
for layer_name, layer_activation in zip(layer_names, activations):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]      
    plt.figure(figsize=(4, 4))
    for i in range(n_features):
        # Display only the first 16 features
        if i >= 16:
            break
        plt.subplot(4, 4, i + 1)
        plt.imshow(layer_activation[0, :, :, i], cmap='viridis')
        plt.axis('off')
    plt.suptitle(f"Layer: {layer_name}")
    plt.show()
# Out:
# 1/1 [==============================] - 0s 334ms/step

# %% [markdown]
# ### 2. Hyperparameter tuning

# %%
# Define a function to create the model
def create_model_resnet18(learning_rate, optimizer_name):
    optimizer_dict = {
    'adam': keras.optimizers.Adam,
    'adagrad': keras.optimizers.Adagrad,
    'rmsprop': keras.optimizers.RMSprop
    }
    if optimizer_name in optimizer_dict:
        optimizer = optimizer_dict[optimizer_name](learning_rate=learning_rate)
    else:
        raise ValueError(f"Unknown optimizer: {optimizer_name}")
    model = ResNet18(input_shape=(32, 32, 1), num_classes=62)
    loss = keras.losses.SparseCategoricalCrossentropy()
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    return model

# %%
# Define the hyperparameters
param_grid = {
    'model__learning_rate': [5e-5, 1e-4, 5e-4],
    'model__optimizer_name': ['adam', 'adagrad','rmsprop']

    # Debug parameters
    # 'model__learning_rate': [1e-5],
    # 'model__optimizer_name': ['adam']
}

# %%
# Wrap the model using KerasClassifier
# Use scikeras.wrappers.KerasClassifier to wrap the model.
keras_model = KerasClassifier(model=create_model_resnet18, epochs=10)

# Perform the grid search
skf = StratifiedKFold(n_splits=3, shuffle=True)
grid = GridSearchCV(estimator=keras_model, param_grid=param_grid

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, std, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, std, param))
# Out:
# Best: 0.852110 using {'model__learning_rate': 0.0005, 'model__optimizer_name': 'adam'}
# 0.845460 (0.001283) with: {'model__learning_rate': 5e-05, 'model__optimizer_name': 'adam'}
# 0.536200 (0.019796) with: {'model__learning_rate': 5e-05, 'model__optimizer_name': 'adagrad'}
# 0.846610 (0.002182) with: {'model__learning_rate': 5e-05, 'model__optimizer_name': 'rmsprop'}
# 0.850400 (0.001727) with: {'model__learning_rate': 0.0001, 'model__optimizer_name': 'adam'}
# 0.653780 (0.005645) with: {'model__learning_rate': 0.0001, 'model__optimizer_name': 'adagrad'}
# 0.848780 (0.002147) with: {'model__learning_rate': 0.0001, 'model__optimizer_name': 'rmsprop'}
# 0.852110 (0.002928) with: {'model__learning_rate': 0.0005, 'model__optimizer_name': 'adam'}
# 0.815020 (0.002322) with: {'model__learning_rate': 0.0005, 'model__optimizer_name': 'adagrad'}
# 0.850820 (0.002643) with: {'model__learning_rate': 0.0005, 'model__optimizer_name': 'rmsprop'}

# %%
# Train the model with the best hyperparameters
best_lr_resnet18 = grid_result.best_params_['model__learning_rate']
best_opt_resnet18 = grid_result.best_params_['model__optimizer_name']
best_model_resnet18 = create_model_resnet18(best_lr_resnet18, best_opt_resnet18)
history = best_model_resnet18.fit(train_dataset.batch(64), validation_data=test_dataset.batch(64), epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 22s 13ms/step - loss: 0.8347 - accuracy: 0.7525 - val_loss: 0.5561 - val_accuracy: 0.8162
# Epoch 2/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.4972 - accuracy: 0.8302 - val_loss: 0.4473 - val_accuracy: 0.8432
# Epoch 3/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.4423 - accuracy: 0.8442 - val_loss: 0.4577 - val_accuracy: 0.8418
# Epoch 4/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.4103 - accuracy: 0.8522 - val_loss: 0.4259 - val_accuracy: 0.8502
# Epoch 5/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3871 - accuracy: 0.8569 - val_loss: 0.4266 - val_accuracy: 0.8519
# Epoch 6/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3661 - accuracy: 0.8634 - val_loss: 0.4346 - val_accuracy: 0.8504
# Epoch 7/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3461 - accuracy: 0.8687 - val_loss: 0.4113 - val_accuracy: 0.8565
# Epoch 8/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3306 - accuracy: 0.8732 - val_loss: 0.4193 - val_accuracy: 0.8547
# Epoch 9/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3184 - accuracy: 0.8764 - val_loss: 0.4514 - val_accuracy: 0.8476
# Epoch 10/10
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.3041 - accuracy: 0.8811 - val_loss: 0.4397 - val_accuracy: 0.8521

# %%
y_pred = best_model_resnet18.predict(test_dataset.batch(64))
y_pred = np.argmax(y_pred, axis=1)
y_true = test_labels

resnet18_accuracy = accuracy_score(y_true, y_pred)
resnet18_precision = precision_score(y_true, y_pred, average='weighted')
resnet18_recall = recall_score(y_true, y_pred, average='weighted')
resnet18_f1 = f1_score(y_true, y_pred, average='weighted')
resnet18_top5_accuracy = top_k_accuracy_score(y_true, best_model_resnet18.predict(test_dataset.batch(64)), k=5)

print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 1s 3ms/step
#  31/313 [=>............................] - ETA: 0s
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      0.86      0.74       976
#            1       0.70      0.87      0.78      1023
#            2       0.97      0.93      0.95      1003
#            3       1.00      0.97      0.98      1035
#            4       0.95      0.98      0.97       903
#            5       0.90      0.95      0.93       928
#            6       0.97      0.95      0.96       959
#            7       0.98      0.99      0.99      1098
#            8       0.97      0.97      0.97       941
#            9       0.95      0.96      0.95       929
#           10       0.94      0.95      0.94       170
#           11       0.81      0.94      0.87       118
#           12       0.78      0.90      0.83       316
#           13       0.82      0.94      0.88       128
#           14       0.89      0.98      0.93       162
#           15       0.81      0.89      0.85       261
#           16       0.84      0.87      0.85        60
#           17       0.82      0.96      0.88        74
#           18       0.58      0.56      0.57       350
#           19       0.76      0.82      0.79        95
#           20       0.62      0.79      0.69        71
#           21       0.89      0.94      0.91       141
#           22       0.77      0.93      0.85       273
#           23       0.94      0.97      0.95       249
#           24       0.69      0.45      0.54       741
#           25       0.87      0.84      0.85       277
#           26       0.86      0.88      0.87        67
#           27       0.93      0.93      0.93       160
#           28       0.84      0.88      0.86       624
#           29       0.93      0.91      0.92       249
#           30       0.78      0.94      0.85       342
#           31       0.62      0.66      0.64       126
#           32       0.64      0.94      0.76       125
#           33       0.65      0.78      0.71        85
#           34       0.80      0.70      0.74       141
#           35       0.41      0.94      0.57        62
#           36       0.88      0.89      0.89       278
#           37       0.81      0.91      0.86       170
#           38       0.43      0.18      0.25        90
#           39       0.96      0.96      0.96       297
#           40       0.99      0.96      0.98       709
#           41       0.32      0.26      0.29        57
#           42       0.55      0.64      0.59        97
#           43       0.95      0.93      0.94       269
#           44       0.80      0.37      0.50        76
#           45       0.87      0.43      0.58        60
#           46       0.68      0.60      0.64        83
#           47       0.50      0.26      0.34       421
#           48       0.46      0.17      0.25        75
#           49       0.95      0.93      0.94       332
#           50       0.00      0.00      0.00        79
#           51       0.48      0.52      0.50        65
#           52       0.73      0.28      0.40        68
#           53       0.91      0.96      0.94       411
#           54       0.00      0.00      0.00        79
#           55       0.95      0.93      0.94       502
#           56       0.62      0.15      0.24        89
#           57       0.53      0.42      0.47        88
#           58       0.87      0.35      0.50        93
#           59       0.75      0.64      0.69       107
#           60       0.57      0.35      0.43        60
#           61       0.63      0.35      0.45        83
#
#     accuracy                           0.85     20000
#    macro avg       0.75      0.73      0.72     20000
# weighted avg       0.84      0.85      0.84     20000
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\conda\envs\tf210\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
models = {
    'Standard CNN': best_std_model,
    'VGG11': best_model_vgg11,
    'ResNet18': best_model_resnet18,
}
acc = {
    'Standard CNN': std_accuracy,
    'VGG11': vgg11_accuracy,
    'ResNet18': resnet18_accuracy,
}
training_time = {
    'Standard CNN': sum(std_time_callback.times),
    'VGG11': sum(vgg11_time_callback.times),
    'ResNet18': sum(resnet18_time_callback.times),
}
reasoning_time = {
    'Standard CNN': measure_reasoning_time(best_std_model, test_images),
    'VGG11': measure_reasoning_time(best_model_vgg11, test_images),
    'ResNet18': measure_reasoning_time(best_model_resnet18, test_images),
} 
    'VGG11': get_flops(best_model_vgg11),
    'ResNet18': get_flops(best_model_resnet18),
}
for name, model in models.items():
    print(f"Model: {name}")
    print(f"Accuracy: {acc[name]:.4f}")
    print(f"Training Time: {training_time[name]:.2f} seconds")
    print(f"Reasoning Time: {reasoning_time[name]:.4f} seconds")
    print(f"FLOPs: {flops[name]:.2f}")
    print("\n"+"\n")
# Out:
# 625/625 [==============================] - 1s 2ms/step
# 625/625 [==============================] - 2s 2ms/step
# 625/625 [==============================] - 2s 3ms/step
# WARNING:tensorflow:From D:\conda\envs\tf210\lib\site-packages\tensorflow\python\ops\nn_ops.py:5250: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# WARNING:tensorflow:From D:\conda\envs\tf210\lib\site-packages\tensorflow\python\ops\nn_ops.py:5250: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Model: Standard CNN
# Accuracy: 0.8641
# Training Time: 334.75 seconds
# Reasoning Time: 1.6170 seconds
# FLOPs: 31915252.00
#
#
#
# Model: VGG11
# Accuracy: 0.8588
# Training Time: 332.03 seconds
# Reasoning Time: 1.7550 seconds
# FLOPs: 268377460.00
#
#
#
# Model: ResNet18
# Accuracy: 0.8520
# Training Time: 442.27 seconds
# Reasoning Time: 2.6060 seconds
# FLOPs: 54152564.00

# %% [markdown]
# ## Comparison

# %%
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-score', 'Top-5 Accuracy']
std_metrics = [std_accuracy, std_precision, std_recall, std_f1, std_top5_accuracy]
vgg11_metrics = [vgg11_accuracy, vgg11_precision, vgg11_recall, vgg11_f1, vgg11_top5_accuracy]
resnet18_metrics = [resnet18_accuracy, resnet18_precision, resnet18_recall, resnet18_f1, resnet18_top5_accuracy]

# Plot the performance metrics
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
for i, metric in enumerate(metrics):
    ax = axes[i//3, i%3]
    ax.bar(['Standard CNN', 'VGG11', 'ResNet18'], [std_metrics[i], vgg11_metrics[i], resnet18_metrics[i]])
    ax.set_title(metric + ' Comparison')
    ax.set_ylabel(metric)
    ax.set_xlabel('Model')
plt.tight_layout()
plt.show()

# %%
# Plot the training time metric
fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(['Standard CNN', 'VGG11', 'ResNet18'], [training_time['Standard CNN'], training_time['VGG11'], training_time['ResNet18']])
ax.set_title('Training Time Comparison')
ax.set_ylabel('Training Time (s)')
ax.set_xlabel('Model')
plt.tight_layout()
plt.show()

# %%
# Plot the reasoning time metric
fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(['Standard CNN', 'VGG11', 'ResNet18'], [reasoning_time['Standard CNN'], reasoning_time['VGG11'], reasoning_time['ResNet18']])
ax.set_title('Reasoning Time Comparison')
ax.set_ylabel('Reasoning Time (s)')
ax.set_xlabel('Model')
plt.tight_layout()
plt.show()

# %%
# Plot the FLOPs metric
fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(['Standard CNN', 'VGG11', 'ResNet18'], [flops['Standard CNN'], flops['VGG11'], flops['ResNet18']])
ax.set_title('FLOPs Comparison')
ax.set_ylabel('FLOPs')
ax.set_xlabel('Model')
plt.tight_layout()
plt.show()
